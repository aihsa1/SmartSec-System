# %% [markdown]
# ## Start

# %%
# !pip install ipykernel
# Out:
# Running cells with 'Python 3.9.7 64-bit ('.venv': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/USER/Desktop/Cyber/PRJ/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import os
import sys
paths = {
    'TENSORFLOW': os.path.join('Tensorflow'),
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'EXPORTED_MODEL_PATH': os.path.join('Tensorflow', 'workspace', 'exported-model'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
}
files = {
    'LABEL_MAP': os.path.join(paths['ANNOTATION_PATH'], "label_map.pbtxt"),
    "EXPORTED_MODEL_PIPELINE": os.path.join(paths["EXPORTED_MODEL_PATH"], "pipeline.config")
}

# %%
for path in paths.values():
  if not os.path.exists(path):
    # !mkdir {path}

# %%
# !pip install tensorflow
# !pip install opencv-python matplotlib
# Out:
# ...
#   Using cached tensorflow-2.7.0-cp39-cp39-win_amd64.whl (430.8 MB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached protobuf-3.19.3-cp39-cp39-win_amd64.whl (895 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.23.1-cp39-cp39-win_amd64.whl (1.5 MB)
# ...
#   Using cached wrapt-1.13.3-cp39-cp39-win_amd64.whl (34 kB)
# ...
#   Using cached grpcio-1.43.0-cp39-cp39-win_amd64.whl (3.4 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached numpy-1.22.1-cp39-cp39-win_amd64.whl (14.7 MB)
# ...
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...

# %%
# !git clone https://github.com/tensorflow/models {paths["APIMODEL_PATH"]}
# Out:
# Cloning into 'Tensorflow\models'...
# Updating files:  24% (709/2861)
# Updating files:  25% (716/2861)
# Updating files:  26% (744/2861)
# Updating files:  27% (773/2861)
# Updating files:  28% (802/2861)
# Updating files:  29% (830/2861)
# Updating files:  30% (859/2861)
# Updating files:  31% (887/2861)
# Updating files:  32% (916/2861)
# Updating files:  33% (945/2861)
# Updating files:  34% (973/2861)
# Updating files:  35% (1002/2861)
# Updating files:  36% (1030/2861)
# Updating files:  37% (1059/2861)
# Updating files:  38% (1088/2861)
# Updating files:  39% (1116/2861)
# Updating files:  40% (1145/2861)
# Updating files:  41% (1174/2861)
# Updating files:  42% (1202/2861)
# Updating files:  43% (1231/2861)
# Updating files:  44% (1259/2861)
# Updating files:  45% (1288/2861)
# Updating files:  46% (1317/2861)
# Updating files:  47% (1345/2861)
# Updating files:  48% (1374/2861)
# Updating files:  49% (1402/2861)
# Updating files:  50% (1431/2861)
# ...

# %%
# !pip install wget
import wget
# Out:
# ...
#   Using cached wget-3.2-py3-none-any.whl
# ...
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\USER\Desktop\Cyber\PRJ\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
url="https://github.com/protocolbuffers/protobuf/releases/download/v3.19.3/protoc-3.19.3-win64.zip"
wget.download(url)
# !move protoc-3.19.3-win64.zip protoc.zip
# !move protoc.zip {paths['PROTOC_PATH']}
# !cd {paths['PROTOC_PATH']} && tar -xf protoc.zip
if os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin')) not in sys.path:
    sys.path.append(os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin')))
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))
# Out:
#         1 file(s) moved.
#         1 file(s) moved.

# %% [markdown]
# ## bad way

# %% [markdown]
# -----------------------------------

# %%
# !pip install apache-beam cython
# Out:
# ...
#   Using cached apache_beam-2.35.0-cp39-cp39-win_amd64.whl
# ...
#   Using cached typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# ...
#   Using cached dill-0.3.1.1-py3-none-any.whl
# ...
#   Using cached httplib2-0.19.1-py3-none-any.whl (95 kB)
# ...
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# ...
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# ...
#   Using cached proto_plus-1.19.8-py3-none-any.whl (45 kB)
# ...
#   Using cached numpy-1.20.3-cp39-cp39-win_amd64.whl (13.7 MB)
# ...
#   Using cached pymongo-3.12.3-cp39-cp39-win_amd64.whl (398 kB)
# ...
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# ...
#   Using cached hdfs-2.6.0-py3-none-any.whl (33 kB)
# ...
#   Using cached pyarrow-6.0.1-cp39-cp39-win_amd64.whl (15.5 MB)
# ...
#   Using cached crcmod-1.7-cp39-cp39-win_amd64.whl
# ...
#   Using cached orjson-3.6.6-cp39-none-win_amd64.whl (180 kB)
# ...
#   Using cached fastavro-1.4.9-cp39-cp39-win_amd64.whl (415 kB)
# ...
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# ...

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools
# Out:
# ...
#   Using cached pip-21.3.1-py3-none-any.whl (1.7 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\USER\\AppData\\Local\\Temp\\pip-uninstall-6d5cecql\\pip.exe'
# Check the permissions.
# ...
#   Using cached setuptools-60.5.0-py3-none-any.whl (958 kB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ...

# %%
# !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
# !cd Tensorflow/models/research/slim && pip install -e .
# Out:
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# C:\Users\USER\Desktop\Cyber\PRJ\.venv\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# C:\Users\USER\Desktop\Cyber\PRJ\.venv\lib\site-packages\setuptools\command\easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# zip_safe flag not set; analyzing archive contents...
# ...

# %%
labels = ["pistol"]
template = '''item {
    id: $
    name: '%'
}
'''
label_map = []
for i in range(len(labels)):
  label_map.append(template)
  label_map[i] = label_map[i].replace("$", str(i + 1))
  label_map[i] = label_map[i].replace("%", labels[i])
print("\n".join(label_map))

with open(os.path.join(paths["ANNOTATION_PATH"], "label_map.pbtxt"), "w") as f:
  f.write("\n".join(label_map))
# Out:
# item {
#     id: 1
#     name: 'pistol'
# }

# %% [markdown]
# ## good way of installation

# %% [markdown]
# -------------------------------------

# %%
# !cd Tensorflow/models/research && for /f %i in ('dir /b object_detection\protos\*.proto') do protoc object_detection\protos\%i --python_out=.
# Out:
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\anchor_generator.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\argmax_matcher.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\bipartite_matcher.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\box_coder.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\box_predictor.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\calibration.proto --python_out=.
#
# (.venv) c:\Users\USER\Desktop\Cyber\PRJ\Tensorflow\models\research>protoc object_detection\protos\center_net.proto --python_out=.
#
# ...

# %%
# !cd Tensorflow/models/research && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build
# Out:
#         1 file(s) copied.
# running build
# running build_py
# copying object_detection\protos\anchor_generator_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\argmax_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\bipartite_matcher_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\box_predictor_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\calibration_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\center_net_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\eval_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_box_coder_pb2.py -> build\lib\object_detection\protos
# copying object_detection\protos\faster_rcnn_pb2.py -> build\lib\object_detection\protos
# ...

# %%
# !pip install --upgrade pip
# !pip install --upgrade setuptools

# %%
# !pip install cython apache-beam

# %%
# !cd Tensorflow/models/research && pip install .
# Out:
# Processing c:\users\user\desktop\cyber\prj\tensorflow\models\research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1663031 sha256=272b6758141a509ae1b4f1de244e0fb0edcfae6f29fc702f4603b24f3908dde1
#   Stored in directory: C:\Users\USER\AppData\Local\Temp\pip-ephem-wheel-cache-7_v10dvj\wheels\50\21\2e\b286edb861ffd9372742d5578de004ee6e97f8fe6b9187fbe6
# Successfully built object-detection
# ...
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# ...

# %%
# !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Obtaining file:///C:/Users/USER/Desktop/Cyber/PRJ/Tensorflow/models/research/slim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Attempting uninstall: slim
#     Found existing installation: slim 0.1
#     Uninstalling slim-0.1:
#       Successfully uninstalled slim-0.1
#   Running setup.py develop for slim
# ...

# %%
# !pip install packaging cycler kiwisolver pyyaml

# %%
# !python {os.path.join(paths["TENSORFLOW"], "models", "research", "object_detection", "builders", "model_builder_tf2_test.py")}
# Out:
# 2022-01-24 07:56:25.319909: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-01-24 07:56:25.320272: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-01-24 07:56:54.025930: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-01-24 07:56:54.026235: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-24 07:56:54.031034: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-HARDOV7
# 2022-01-24 07:56:54.031313: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-HARDOV7
# Running tests under Python 3.9.7: C:\Users\USER\Desktop\Cyber\PRJ\.venv\Scripts\python.exe
# ...

# %%
import object_detection

# %%
labels = ["pistol"]
template = '''item {
    id: $
    name: '%'
}
'''
label_map = []
for i in range(len(labels)):
  label_map.append(template)
  label_map[i] = label_map[i].replace("$", str(i + 1))
  label_map[i] = label_map[i].replace("%", labels[i])
print("\n".join(label_map))

with open(os.path.join(paths["ANNOTATION_PATH"], "label_map.pbtxt"), "w") as f:
  f.write("\n".join(label_map))
# Out:
# item {
#     id: 1
#     name: 'pistol'
# }

# %%
# !pip install PySimpleGUI autopep8

# %%
# !pip install pycryptodome

# %%
# !pip install pymongo "pymongo[srv]"

# %%
import json
import cv2
cap = cv2.VideoCapture(0)
WIDTH_WEBCAM = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
HEIGHT_WEBCAM = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()

with open(os.path.join("Configs", "dimensions.json"), "w") as f:
    json.dump(
        {"w": WIDTH_WEBCAM, "h": HEIGHT_WEBCAM},
        f
    )

# %% [markdown]
# ## IMPORT MODEL (4000 GITHUB + MAKEML)
